# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding, GlobalMaxPooling1D, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from gensim.models import Word2Vec
# Out:
# WARNING:tensorflow:From C:\Users\minhd\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import pandas as pd

# Đọc trực tiếp file JSON thành DataFrame
df = pd.read_json('devset_images_metadata.json')

# Nếu cần chuyển đổi từ cột chứa danh sách các đối tượng thành các cột DataFrame
df = pd.json_normalize(df['images'])

# Hiển thị DataFrame
df.head()
# Out:
#                                          description  \
# 0                                               None
# 1                                               None
# 2  After the flood, the boarded up stores bear up...
# 3                                               None
# 4                                               None
#
#                                            user_tags                   title  \
# 0                 [2009 road trip, obrero road trip]         Biltmore Estate
# 1   [daulatabad, daulatabad fort, ellora, road trip]             Chand Minar
# 2  [cedarrapids, createsouthroadtrip2009, disaste...      Uplifting Graffiti
# 3          [cork, enchente, flood, ireland, irlanda]                DSCF6487
# 4  [athens georgia, brown, current, flood, mud, r...  Oconoe river - flooded
#
#                                  license_name     user_nsid  \
# 0  Attribution-NonCommercial-NoDerivs License  95156977@N00
# 1              Attribution-ShareAlike License  24574470@N00
# 2                         Attribution License  73451168@N00
# 3  Attribution-NonCommercial-NoDerivs License  12947023@N00
# 4                         Attribution License  60704492@N00
#
#   image_extension_original  longitude    image_id  \
# 0                      jpg        NaN  3519864665
# 1                      jpg  75.200386  4896119055
# 2                      jpg        NaN  3468473862
# 3                      jpg  -8.621177  4120853942
# 4                      jpg -83.368265  4436083254
#
#                                          license_url date_uploaded  \
# 0  http://creativecommons.org/licenses/by-nc-nd/2.0/    1242004112
# 1     http://creativecommons.org/licenses/by-sa/2.0/    1281931224
# 2        http://creativecommons.org/licenses/by/2.0/    1240493762
# 3  http://creativecommons.org/licenses/by-nc-nd/2.0/    1258754762
# 4        http://creativecommons.org/licenses/by/2.0/    1268676971
#
#               date_taken   latitude  \
# 0  2009-05-10 08:27:33.0        NaN
# 1  2010-08-14 13:35:10.0  19.939383
# 2  2009-04-21 18:07:56.0        NaN
# 3  2009-11-20 15:16:40.0  51.889603
# 4  2010-03-13 15:14:04.0  33.949149
#
#                                            image_url        user_nickname  \
# 0  http://www.flickr.com/photos/95156977@N00/3519...  5 Flip-Flops (Earl)
# 1  http://www.flickr.com/photos/24574470@N00/4896...           sankarshan
# 2  http://www.flickr.com/photos/73451168@N00/3468...              J Wynia
# 3  http://www.flickr.com/photos/12947023@N00/4120...             guileite
# 4  http://www.flickr.com/photos/60704492@N00/4436...              The_Gut
#
#                 capture_device
# 0   Canon EOS DIGITAL REBEL XT
# 1  NIKON CORPORATION NIKON D90
# 2            Panasonic DMC-TZ5
# 3     FUJIFILM FinePix S6000fd
# 4      Canon PowerShot SX10 IS

# %%
train_label = pd.read_csv('devset_images_gt.csv')
train_label.head()
# Out:
#            id  label
# 0  3519864665      0
# 1  4896119055      0
# 2  3468473862      0
# 3  4120853942      0
# 4  4436083254      0

# %%
train_label.rename(columns = {'id': 'image_id', 'label': 'train_y'}, inplace = True)
train_label.head()
# Out:
#      image_id  train_y
# 0  3519864665        0
# 1  4896119055        0
# 2  3468473862        0
# 3  4120853942        0
# 4  4436083254        0

# %%
data = pd.concat([df, train_label], axis = 1)
data.head()
# Out:
#                                          description  \
# 0                                               None
# 1                                               None
# 2  After the flood, the boarded up stores bear up...
# 3                                               None
# 4                                               None
#
#                                            user_tags                   title  \
# 0                 [2009 road trip, obrero road trip]         Biltmore Estate
# 1   [daulatabad, daulatabad fort, ellora, road trip]             Chand Minar
# 2  [cedarrapids, createsouthroadtrip2009, disaste...      Uplifting Graffiti
# 3          [cork, enchente, flood, ireland, irlanda]                DSCF6487
# 4  [athens georgia, brown, current, flood, mud, r...  Oconoe river - flooded
#
#                                  license_name     user_nsid  \
# 0  Attribution-NonCommercial-NoDerivs License  95156977@N00
# 1              Attribution-ShareAlike License  24574470@N00
# 2                         Attribution License  73451168@N00
# 3  Attribution-NonCommercial-NoDerivs License  12947023@N00
# 4                         Attribution License  60704492@N00
#
#   image_extension_original  longitude    image_id  \
# 0                      jpg        NaN  3519864665
# 1                      jpg  75.200386  4896119055
# 2                      jpg        NaN  3468473862
# 3                      jpg  -8.621177  4120853942
# 4                      jpg -83.368265  4436083254
#
#                                          license_url date_uploaded  \
# 0  http://creativecommons.org/licenses/by-nc-nd/2.0/    1242004112
# 1     http://creativecommons.org/licenses/by-sa/2.0/    1281931224
# 2        http://creativecommons.org/licenses/by/2.0/    1240493762
# 3  http://creativecommons.org/licenses/by-nc-nd/2.0/    1258754762
# 4        http://creativecommons.org/licenses/by/2.0/    1268676971
#
#               date_taken   latitude  \
# 0  2009-05-10 08:27:33.0        NaN
# 1  2010-08-14 13:35:10.0  19.939383
# 2  2009-04-21 18:07:56.0        NaN
# 3  2009-11-20 15:16:40.0  51.889603
# 4  2010-03-13 15:14:04.0  33.949149
#
#                                            image_url        user_nickname  \
# 0  http://www.flickr.com/photos/95156977@N00/3519...  5 Flip-Flops (Earl)
# 1  http://www.flickr.com/photos/24574470@N00/4896...           sankarshan
# 2  http://www.flickr.com/photos/73451168@N00/3468...              J Wynia
# 3  http://www.flickr.com/photos/12947023@N00/4120...             guileite
# 4  http://www.flickr.com/photos/60704492@N00/4436...              The_Gut
#
#                 capture_device    image_id  train_y
# 0   Canon EOS DIGITAL REBEL XT  3519864665        0
# 1  NIKON CORPORATION NIKON D90  4896119055        0
# 2            Panasonic DMC-TZ5  3468473862        0
# 3     FUJIFILM FinePix S6000fd  4120853942        0
# 4      Canon PowerShot SX10 IS  4436083254        0

# %%
def preprocess_user_tags(tags):
    if isinstance(tags, list):
        return ' '.join(tags)
    elif pd.isnull(tags):
        return '[NULL]'
    else:
        return tags

data['user_tags'] = data['user_tags'].apply(preprocess_user_tags)

# %%
data['text'] = data[['description', 'user_tags','title']].apply(lambda x: ' | '.join(x.dropna()), axis=1)
data['text']
# Out:
# 0       2009 road trip obrero road trip | Biltmore Estate
# 1       daulatabad daulatabad fort ellora road trip | ...
# 2       After the flood, the boarded up stores bear up...
# 3          cork enchente flood ireland irlanda | DSCF6487
# 4       athens georgia brown current flood mud river s...
#                               ...
# 5275    550d camino canon canoneos550d canoneoskissx4 ...
# 5276    albany, ny flood walk water | Albany's Corning...
# 5277                al the waters in pike road | IMG_4989
# 5278    2013 Fair Flood | 2013 county fair flood linn ...
# 5279    Alcatraz trip, San Francisco |  | Prison building
# Name: text, Length: 5280, dtype: object

# %%
texts = data['text'].tolist()
labels = data['train_y'].tolist()  # Replace 'label_column_name' with the actual column name

# %%
# Hyperparameters
vocab_size = 10000
embedding_dim = 100
max_length = 20
padding_type = 'post'
truncating_type = 'post'

# Tokenize the text
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
word_index = tokenizer.word_index

# Convert texts to sequences
sequences = tokenizer.texts_to_sequences(texts)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=truncating_type)

# %%
# Train Word2Vec model
w2v_model = Word2Vec(sentences=[text.split() for text in texts], vector_size=embedding_dim, window=5, min_count=1, workers=4)
w2v_model.save("word2vec.model")

# Create an embedding matrix
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size:
        try:
            embedding_vector = w2v_model.wv[word]
            embedding_matrix[i] = embedding_vector
        except KeyError:
            continue

# %%
# Build the model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_length, trainable=False),
    GlobalMaxPooling1D(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\minhd\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\minhd\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 100)           1000000
#
#  global_max_pooling1d (Glob  (None, 100)               0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 512)               51712
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1052225 (4.01 MB)
# Trainable params: 52225 (204.00 KB)
# Non-trainable params: 1000000 (3.81 MB)
# _________________________________________________________________

# %%
# Convert labels to numpy array
labels = np.array(labels)

# Train the model
history = model.fit(padded_sequences, labels, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\minhd\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\minhd\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 132/132 [==============================] - 1s 4ms/step - loss: 0.6501 - accuracy: 0.6326 - val_loss: 0.6241 - val_accuracy: 0.6742
# Epoch 2/10
# 132/132 [==============================] - 0s 1ms/step - loss: 0.6147 - accuracy: 0.6681 - val_loss: 0.6252 - val_accuracy: 0.6307
# Epoch 3/10
# 132/132 [==============================] - 0s 1ms/step - loss: 0.6064 - accuracy: 0.6780 - val_loss: 0.6073 - val_accuracy: 0.6875
# Epoch 4/10
# 132/132 [==============================] - 0s 1ms/step - loss: 0.5981 - accuracy: 0.6811 - val_loss: 0.6162 - val_accuracy: 0.6373
# Epoch 5/10
# 132/132 [==============================] - 0s 1ms/step - loss: 0.5925 - accuracy: 0.6844 - val_loss: 0.6093 - val_accuracy: 0.7036
# Epoch 6/10
# 132/132 [==============================] - 0s 2ms/step - loss: 0.5945 - accuracy: 0.6849 - val_loss: 0.5903 - val_accuracy: 0.6998
# Epoch 7/10
# 132/132 [==============================] - 0s 1ms/step - loss: 0.5928 - accuracy: 0.6889 - val_loss: 0.5913 - val_accuracy: 0.7150
# Epoch 8/10
# 132/132 [==============================] - 0s 1ms/step - loss: 0.5781 - accuracy: 0.7015 - val_loss: 0.5776 - val_accuracy: 0.7131
# Epoch 9/10
# 132/132 [==============================] - 0s 1ms/step - loss: 0.5729 - accuracy: 0.6953 - val_loss: 0.5801 - val_accuracy: 0.7008
# Epoch 10/10
# 132/132 [==============================] - 0s 1ms/step - loss: 0.5666 - accuracy: 0.7100 - val_loss: 0.5682 - val_accuracy: 0.7273

# %%
def preprocess_text(text, tokenizer, max_length, padding_type='post', truncating_type='post'):
    # Convert text to sequences
    sequences = tokenizer.texts_to_sequences([text])
    # Pad the sequences
    padded_sequence = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=truncating_type)
    return padded_sequence


def predict(text, model, tokenizer, max_length):
    # Preprocess the text
    padded_sequence = preprocess_text(text, tokenizer, max_length)
    # Make prediction
    prediction = model.predict(padded_sequence)
    # Convert probability to class label (0 or 1)
    return prediction

# %%
test_df = pd.read_csv('test.csv')
test_df
# Out:
#         image_id                                              title  \
# 0     3483809003  Flooded Parking Lot At Emily Fowler Library, A...
# 1     3712805295             L'arc de Barà / The roman arch of Barà
# 2      379845620  Highest point over the sea level that is reach...
# 3     7343264988                              Lagos after the rains
# 4     3843337492                                 flooded Corley Ave
# ...          ...                                                ...
# 1315  6452132743  Landscapes and cityscapes: daily dose of ugliness
# 1316   244899140     A cool looking building the the Parque Central
# 1317  3073018258                                     Just Plain Wet
# 1318    49525361                                         ... Palmer
# 1319   537780925                    Day 5. Halifax’s Public Gardens
#
#                                             description  \
# 0     Denton Creek overflows its banks and floods Oa...
# 1     Sembla que fou dedicat a August entorn l'any 1...
# 2                                                   NaN
# 3     After heavy rain, Lagos (Nigeria) was still fl...
# 4     also a local black out due to the tree branch ...
# ...                                                 ...
# 1315  You can find more like this in my Landscapes a...
# 1316                                                NaN
# 1317  I liked the reflection of the trees on the wet...
# 1318  Looking up toward Magnolia. Our neighbor's hou...
# 1319                                                NaN
#
#                                               user_tags
# 0                       project, slis 5715, spring 2009
# 1     arc, arc_de_berà, arch, archaeology, arco, arq...
# 2                                                   NaN
# 3                                africa, lagos, nigeria
# 4                                 flood, storm, toronto
# ...                                                 ...
# 1315  bouw, bus station, commuting, construction, da...
# 1316                                    guatemala, xela
# 1317  driving, fall, me, november, photographing, ra...
# 1318       hurricane katrina, new orleans, post katrina
# 1319  canada, flowers, halifax, nova scotia, public ...
#
# [1320 rows x 4 columns]

# %%
test_df['text'] = test_df[['description', 'user_tags','title']].apply(lambda x: ' | '.join(x.dropna()), axis=1)

# %%
test_df['text'] = test_df['text'].apply(preprocess_user_tags)
test_texts = test_df['text'].to_list()

# %%
predicted_classes = predict(test_texts, model, tokenizer, max_length)
print(predicted_classes)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [[0.44359463]]
